# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
d1=pd.read_csv(r"C:\Users\priya\Downloads\matches.csv-20231125T091826Z-001\matches.csv")
d2=pd.read_csv(r"C:\Users\priya\Downloads\deliveries.csv-20231125T091826Z-001\deliveries.csv")

# %%
left=d1, right=d2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 left=d1, right=d2
#
# ValueError: too many values to unpack (expected 2)

# %%
d1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   season           756 non-null    int64
#  2   city             749 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   dl_applied       756 non-null    int64
#  10  winner           752 non-null    object
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  752 non-null    object
#  14  venue            756 non-null    object
#  15  umpire1          754 non-null    object
#  16  umpire2          754 non-null    object
# ...

# %%
d2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 179078 entries, 0 to 179077
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          179078 non-null  int64
#  1   inning            179078 non-null  int64
#  2   batting_team      179078 non-null  object
#  3   bowling_team      179078 non-null  object
#  4   over              179078 non-null  int64
#  5   ball              179078 non-null  int64
#  6   batsman           179078 non-null  object
#  7   non_striker       179078 non-null  object
#  8   bowler            179078 non-null  object
#  9   is_super_over     179078 non-null  int64
#  10  wide_runs         179078 non-null  int64
#  11  bye_runs          179078 non-null  int64
#  12  legbye_runs       179078 non-null  int64
#  13  noball_runs       179078 non-null  int64
#  14  penalty_runs      179078 non-null  int64
#  15  batsman_runs      179078 non-null  int64
# ...

# %%
d1.describe(include='object')
# Out:
#           city        date           team1                        team2  \
# count      749         756             756                          756
# unique      32         546              15                           15
# top     Mumbai  2011-04-17  Mumbai Indians  Royal Challengers Bangalore
# freq       101           2             101                           95
#
#            toss_winner toss_decision  result          winner player_of_match  \
# count              756           756     756             752             752
# unique              15             2       3              15             226
# top     Mumbai Indians         field  normal  Mumbai Indians        CH Gayle
# freq                98           463     743             109              21
#
#                venue          umpire1        umpire2      umpire3
# count            756              754            754          119
# unique            41               61             65           25
# ...

# %%
d2.describe(include='object')
# Out:
#           batting_team    bowling_team  batsman non_striker           bowler  \
# count           179078          179078   179078      179078           179078
# unique              15              15      516         511              405
# top     Mumbai Indians  Mumbai Indians  V Kohli    SK Raina  Harbhajan Singh
# freq             22619           22517     4211        4173             3451
#
#        player_dismissed dismissal_kind   fielder
# count              8834           8834      6448
# unique              487              9       499
# top            SK Raina         caught  MS Dhoni
# freq                162           5348       159

# %%
d2.describe()
# Out:
#             match_id         inning           over           ball  \
# count  179078.000000  179078.000000  179078.000000  179078.000000
# mean     1802.252957       1.482952      10.162488       3.615587
# std      3472.322805       0.502074       5.677684       1.806966
# min         1.000000       1.000000       1.000000       1.000000
# 25%       190.000000       1.000000       5.000000       2.000000
# 50%       379.000000       1.000000      10.000000       4.000000
# 75%       567.000000       2.000000      15.000000       5.000000
# max     11415.000000       5.000000      20.000000       9.000000
#
#        is_super_over      wide_runs       bye_runs    legbye_runs  \
# count  179078.000000  179078.000000  179078.000000  179078.000000
# mean        0.000452       0.036721       0.004936       0.021136
# std         0.021263       0.251161       0.116480       0.194908
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
d1.describe()
# Out:
#                  id       season  dl_applied  win_by_runs  win_by_wickets
# count    756.000000   756.000000  756.000000   756.000000      756.000000
# mean    1792.178571  2013.444444    0.025132    13.283069        3.350529
# std     3464.478148     3.366895    0.156630    23.471144        3.387963
# min        1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%      189.750000  2011.000000    0.000000     0.000000        0.000000
# 50%      378.500000  2013.000000    0.000000     0.000000        4.000000
# 75%      567.250000  2016.000000    0.000000    19.000000        6.000000
# max    11415.000000  2019.000000    1.000000   146.000000       10.000000

# %%
d1['season'].value_counts()
# Out:
# 2013    76
# 2012    74
# 2011    73
# 2010    60
# 2014    60
# 2016    60
# 2018    60
# 2019    60
# 2017    59
# 2015    59
# 2008    58
# 2009    57
# Name: season, dtype: int64

# %%
d1['season'].mode()
# Out:
# 0    2013
# Name: season, dtype: int64

# %%
d1.loc[(d1['winner']=='Mumbai Indians')&(d1['season']==2011)]
# Out:
#       id  season       city        date                        team1  \
# 237  238    2011      Delhi  2011-04-10             Delhi Daredevils
# 241  242    2011  Bangalore  2011-04-12  Royal Challengers Bangalore
# 253  254    2011     Mumbai  2011-04-20                Pune Warriors
# 256  257    2011     Mumbai  2011-04-22               Mumbai Indians
# 259  260    2011  Hyderabad  2011-04-24               Mumbai Indians
# 272  273    2011     Mumbai  2011-05-02               Mumbai Indians
# 276  277    2011     Mumbai  2011-05-04               Mumbai Indians
# 281  282    2011     Mumbai  2011-05-07               Mumbai Indians
# 302  303    2011    Kolkata  2011-05-22        Kolkata Knight Riders
# 304  305    2011     Mumbai  2011-05-25        Kolkata Knight Riders
#
#                    team2          toss_winner toss_decision  result  \
# 237       Mumbai Indians     Delhi Daredevils           bat  normal
# 241       Mumbai Indians       Mumbai Indians         field  normal
# ...

# %%
sns.countplot(d1,x='toss_decision')
# Out:
# <Axes: xlabel='toss_decision', ylabel='count'>

# %%
plt.pie(d1['toss_decision'].value_counts(normalize=True)*100,autopct='%1.1f%%')
plt.show()

# %%
d=d1[(d1['toss_decision'] == 'field') & (d1['toss_winner'] == d1['winner'])]
d
# Out:
#         id  season           city        date                   team1  \
# 1        2    2017           Pune  2017-04-06          Mumbai Indians
# 2        3    2017         Rajkot  2017-04-07           Gujarat Lions
# 3        4    2017         Indore  2017-04-08  Rising Pune Supergiant
# 5        6    2017      Hyderabad  2017-04-09           Gujarat Lions
# 6        7    2017         Mumbai  2017-04-09   Kolkata Knight Riders
# ..     ...     ...            ...         ...                     ...
# 749  11345    2019      Bengaluru    04/05/19     Sunrisers Hyderabad
# 750  11346    2019         Mohali    05/05/19     Chennai Super Kings
# 751  11347    2019         Mumbai    05/05/19   Kolkata Knight Riders
# 753  11413    2019  Visakhapatnam    08/05/19     Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam    10/05/19          Delhi Capitals
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
d_y = d.groupby('season').size().reset_index(name='count')
d_y
# Out:
#     season  count
# 0     2008     19
# 1     2009     14
# 2     2010     10
# 3     2011     27
# 4     2012     18
# 5     2013     15
# 6     2014     24
# 7     2015     14
# 8     2016     32
# 9     2017     28
# 10    2018     27
# 11    2019     31

# %%
most_wins_year = d_y[d_y['count'] == d_y['count'].max()]
most_wins_year
# Out:
#    season  count
# 8    2016     32

# %%
y=d1.loc[d1['season']==2019]
y
# Out:
#         id  season           city      date                        team1  \
# 696  11137    2019        Chennai  23/03/19  Royal Challengers Bangalore
# 697  11138    2019        Kolkata  24/03/19          Sunrisers Hyderabad
# 698  11139    2019         Mumbai  24/03/19               Delhi Capitals
# 699  11140    2019         Jaipur  25/03/19              Kings XI Punjab
# 700  11141    2019          Delhi  26/03/19               Delhi Capitals
# 701  11142    2019        Kolkata  27/03/19        Kolkata Knight Riders
# 702  11143    2019      Bengaluru  28/03/19               Mumbai Indians
# 703  11144    2019      Hyderabad  29/03/19             Rajasthan Royals
# 704  11145    2019         Mohali  30/03/19               Mumbai Indians
# 705  11146    2019          Delhi  30/03/19        Kolkata Knight Riders
# 706  11147    2019      Hyderabad  31/03/19          Sunrisers Hyderabad
# 707  11148    2019        Chennai  31/03/19          Chennai Super Kings
# ...

# %%
d3=d1.loc[(d1['season']==2019)&(d1['player_of_match']==d1['player_of_match'])]

# %%
d3['player_of_match'].mode()
# Out:
# 0    AD Russell
# Name: player_of_match, dtype: object

# %%
d2
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 179073     11415       2  Chennai Super Kings               Mumbai Indians
# 179074     11415       2  Chennai Super Kings               Mumbai Indians
# 179075     11415       2  Chennai Super Kings               Mumbai Indians
# 179076     11415       2  Chennai Super Kings               Mumbai Indians
# 179077     11415       2  Chennai Super Kings               Mumbai Indians
#
# ...

# %%
d2['bowler'].mode()
# Out:
# 0    Harbhajan Singh
# Name: bowler, dtype: object

# %%
k=d2.loc[(d2['batsman']=='V Kohli'),['batsman','ball']]

# %%
k['ball']
# Out:
# 2590      2
# 2591      3
# 2593      5
# 2594      6
# 2597      1
#          ..
# 177522    7
# 177523    1
# 177524    2
# 177525    3
# 177527    5
# Name: ball, Length: 4211, dtype: int64

# %%
k1=d2.loc[(d2['batsman']=='V Kohli'),['total_runs','ball']]

# %%
k1['total_runs']
# Out:
# 2590      1
# 2591      1
# 2593      0
# 2594      1
# 2597      0
#          ..
# 177522    1
# 177523    4
# 177524    6
# 177525    1
# 177527    0
# Name: total_runs, Length: 4211, dtype: int64

# %%
s_r=(k1['total_runs']/k['ball'])*100
s_r
# Out:
# 2590       50.000000
# 2591       33.333333
# 2593        0.000000
# 2594       16.666667
# 2597        0.000000
#              ...
# 177522     14.285714
# 177523    400.000000
# 177524    300.000000
# 177525     33.333333
# 177527      0.000000
# Length: 4211, dtype: float64

# %%
b=d2.loc[(d2['bowler']==d2['bowler'])&(d2['extra_runs']==d2['extra_runs'].max()),['bowler']]

# %%
b['bowler'].max()
# Out:
# 'SL Malinga'

# %%
d1['venue'].mode()
# Out:
# 0    Eden Gardens
# Name: venue, dtype: object

# %%
w=d1.loc[(d1['season']==2017)&(d1['team1']=='Sunrisers Hyderabad')&(d1['team2']=='Royal Challengers Bangalore')]

# %%
w['player_of_match']
# Out:
# 0    Yuvraj Singh
# Name: player_of_match, dtype: object

# %%
j=d2.loc[(d2['batsman']=='V Kohli')&(d2['bowler']=='JJ Bumrah')]
j
# Out:
#         match_id  inning                 batting_team    bowling_team  over  \
# 2633          12       1  Royal Challengers Bangalore  Mumbai Indians     8
# 2634          12       1  Royal Challengers Bangalore  Mumbai Indians     8
# 2635          12       1  Royal Challengers Bangalore  Mumbai Indians     8
# 2637          12       1  Royal Challengers Bangalore  Mumbai Indians     8
# 2638          12       1  Royal Challengers Bangalore  Mumbai Indians     8
# ...          ...     ...                          ...             ...   ...
# 166347     11143       2  Royal Challengers Bangalore  Mumbai Indians     4
# 166348     11143       2  Royal Challengers Bangalore  Mumbai Indians     4
# 166349     11143       2  Royal Challengers Bangalore  Mumbai Indians     4
# 166406     11143       2  Royal Challengers Bangalore  Mumbai Indians    14
# 166408     11143       2  Royal Challengers Bangalore  Mumbai Indians    14
#
# ...

# %%
j['total_runs'].sum()
# Out:
# 114

# %%
d2['player_dismissed'].mode()
# Out:
# 0    SK Raina
# Name: player_dismissed, dtype: object

# %%
d1['player_of_match'].mode()
# Out:
# 0    CH Gayle
# Name: player_of_match, dtype: object
